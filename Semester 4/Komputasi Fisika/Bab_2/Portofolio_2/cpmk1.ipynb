# %% [markdown]
# Capaian Pembelajaran
# Memahami dan memanipulasi ekspresi matematika untuk menetapkan dasar sebagai teknik interpolasi

# %% [markdown]
# Interpolasi
#
# Memahami dan memanipulasi ekspresi matematika adalah langkah penting dalam menetapkan dasar untuk berbagai teknik interpolasi. Interpolasi adalah metode untuk menemukan fungsi yang melewati sekumpulan titik data, sehingga memungkinkan kita untuk memperkirakan nilai di antara titik-titik tersebut. Untuk melakukan ini, kita perlu memanfaatkan polinomial atau fungsi lain yang dapat diatur untuk cocok dengan titik data yang ada.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Titik data
x = np.array([0.5, 2.0, 4.0, 5.0, 7.0, 9.0])
y = np.array([0.5, 0.4, 0.3, 0.1, 0.9, 0.8])

# Derajat polinomial
degree = 3

# Menyesuaikan polinomial pada titik data
coefficients = np.polyfit(x, y, degree)

# Membuat fungsi polinomial dari koefisien
polynomial = np.poly1d(coefficients)

# Menampilkan koefisien polinomial
print("Koefisien polinomial:", coefficients)

# Membuat nilai x baru untuk evaluasi polinomial
x_new = np.linspace(min(x), max(x), 100)
y_new = polynomial(x_new)

# Plotting data asli dan polinomial hasil interpolasi
plt.scatter(x, y, color='red', label='Titik Data Asli')
plt.plot(x_new, y_new, label='Polinomial Interpolasi')
plt.xlabel('x')
plt.ylabel('y')
plt.title(f'Interpolasi Polinomial Derajat {degree}')
plt.legend()
plt.show()
# Out:
# Koefisien polinomial: [-0.00552147  0.09889271 -0.43193108  0.75909819]
